# %% [markdown]
# # Noise Reduction Version 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img = plt.imread('IMG_3037.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.axis('off')
plt.imshow(img, cmap='gray')
plt.show()

# %%
img = plt.imread('IMG_3037.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

blur_image = cv2.blur(img, (30, 30))
plt.axis('off')
plt.imshow(blur_image, cmap='gray')
plt.show()

# %%
img = plt.imread('IMG_3037.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

blur_image = cv2.GaussianBlur(img, (21, 21), 0)
plt.axis('off')
plt.imshow(blur_image, cmap='gray')
plt.show()

# %%
img = plt.imread('IMG_3037.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

blur_image = cv2.medianBlur(img, 5)
plt.axis('off')
plt.imshow(blur_image, cmap='gray')
plt.show()

# %%
img = plt.imread('IMG_3037.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

blur_image = cv2.bilateralFilter(img, 22, 200, 200)
plt.axis('off')
plt.imshow(blur_image, cmap='gray')
plt.show()

# %%
def threshold(img, threshold=0.5):
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            img[i,j] = 1 if img[i,j] > threshold else 0

# %%
# Intresting
img = plt.imread('/Users/matteoblack/Desktop/Proj/visi-solve/noise-reduction/IMG_3037.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
threshold(img)

for i in range(5):
    img = cv2.blur(img, (10, 10))
    threshold(img)



plt.axis('off')
plt.imshow(img, cmap='gray')
plt.show()

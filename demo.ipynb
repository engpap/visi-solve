# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Let's try solve this equation with a clean background

# %%
img = cv2.imread('./eq_no_noise.png', 0)
plt.imshow(img, cmap='gray')
plt.show()

# %%
# !python pipeline.py -n 2 -s 2 -f ./eq_no_noise.png
# Out:
# The result of 12/3 is 4.0.

# %% [markdown]
# # Let's try solve this equation with some noise

# %%
img = cv2.imread('./eq_noise.png', 0)
plt.imshow(img, cmap='gray')
plt.show()

# %%
# !python pipeline.py -n 1 -s 2 -f ./eq_noise.png
# Out:
# The result of 13+5 is 18.

# %% [markdown]
# # Let's try to solve this equation with some shadow

# %%
img = cv2.imread('./eq_shadow.png', 0)
plt.imshow(img, cmap='gray')
plt.show()

# %%
# !python pipeline.py -n 2 -s 2 -f ./eq_shadow.png
# Out:
# The result of 62-40 is 22.

# %% [markdown]
# # Let's try to solve some bad written equation
# ## Here, the 4 looks like a 9. Indeed, it's miss-predicted.

# %% [markdown]
# img = cv2.imread('./eq_rejected.png', 0)
# plt.imshow(img, cmap='gray')
# plt.show()

# %%
img = cv2.imread('./eq_rejected.png', 0)
plt.imshow(img, cmap='gray')
plt.show()

# %%
# !python pipeline.py -n 1 -s 2 -f ./eq_rejected.png
# Out:
# 0: 0.01%
# 1: 0.02%
# 2: 0.00%
# 3: 0.00%
# 4: 48.95%
# 5: 0.00%
# 6: 0.40%
# 7: 0.00%
# 8: 0.12%
# 9: 48.83%
# 10: 0.00%
# 11: 0.00%
# 12: 0.00%
# 13: 1.66%
#
# Confidence too low for reliable prediction - Got 48.95% confidence.
# Try with a better image.
